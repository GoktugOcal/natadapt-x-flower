# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("projects/test_1_fed_sim_NIID_alpha05/federated.txt")
df[df["Dataset"] == "test"].pivot(index="RoundNo", columns="ClientNo", values="Accuracy").plot()
# Out:
# <Axes: xlabel='RoundNo'>

# %%
df_clients = df[df["ClientNo"] != "server"]

df_clients[["RoundNo", "Accuracy"]].groupby("RoundNo").mean().plot()
# Out:
# <Axes: xlabel='RoundNo'>

# %%
df.dtypes
# Out:
# RoundNo       int64
# ClientNo     object
# Dataset      object
# Accuracy    float64
# dtype: object
