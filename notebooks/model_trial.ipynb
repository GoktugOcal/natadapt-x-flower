# %%
import sys
# setting path
sys.path.append('../')
import os
import numpy as np

import nets as models
import functions as fns

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import time
import pickle

DEVICE = "cuda"

class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def get_avg(self):
        return self.avg
    
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        # print(val, self.sum, self.count, n)
        
def compute_accuracy(output, target, debug=False):
    output = output.argmax(dim=1)
    acc = 0.0
    acc = torch.sum(target == output).item()
    acc = acc/output.size(0)*100
    if debug:
        print(target)
        print(output)
        input()
    # print(acc)
    return acc

def eval(test_loader, model, debug=False):
    batch_time = AverageMeter()
    acc = AverageMeter()

    # switch to eval mode
    model.eval()

    end = time.time()
    for i, (images, target) in enumerate(test_loader):

        if len(target.shape) > 1: target = target.reshape(len(target))

        images = images.to(DEVICE)
        target = target.to(DEVICE)
        
        output = model(images)
        batch_acc = compute_accuracy(output, target, debug=debug)
        acc.update(batch_acc, images.size(0))
        # batch_time.update(time.time() - end)
        end = time.time()

        # Update statistics
        # estimated_time_remained = batch_time.get_avg()*(len(test_loader)-i-1)
        # fns.update_progress(i, len(test_loader), 
        #     ESA='{:8.2f}'.format(estimated_time_remained)+'s',
        #     acc='{:4.2f}'.format(float(batch_acc))
        #     )
    print('Test accuracy: {:4.2f}% (time = {:8.2f}s)'.format(
            float(acc.get_avg()), batch_time.get_avg()*len(test_loader)))
    # print('===================================================================')
    return float(acc.get_avg())

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])
train_dataset = datasets.CIFAR100(root="../data", train=True, download=True,
    transform=transform)
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=128, shuffle=True,
    num_workers=1, pin_memory=True)
test_dataset = datasets.CIFAR100(root="../data", train=False, download=True,
    transform=transform)
test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=128, shuffle=True,
    num_workers=1, pin_memory=True)

global_model = torch.load("../projects/pretrained_model/cifar100_predefined_a03_56c_fedavg/last_model.pth.tar")

global_train_acc = eval(train_loader, global_model, debug=False)
global_test_acc = eval(test_loader, global_model, debug=False)

print("Train :", global_train_acc)
print("Test :", global_test_acc)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Test accuracy: 79.93% (time =     0.00s)
# Test accuracy: 80.54% (time =     0.00s)
# Train : 79.928
# Test : 80.54

# %%
for client_id in range(56):
    train_dataset_path = os.path.join("../data/32_Cifar100_NIID_56c_a03_fix", "train", f"{client_id}.pkl")
    train_data = pickle.load(open(train_dataset_path, "rb"))
    train_loader = torch.utils.data.DataLoader(
        train_data,
        batch_size=128,
        shuffle=True)

    test_dataset_path = os.path.join("../data/32_Cifar100_NIID_56c_a03_fix", "test", f"{client_id}.pkl")
    test_data = pickle.load(open(test_dataset_path, "rb"))
    test_loader = torch.utils.data.DataLoader(
        test_data,
        batch_size=128,
        shuffle=True)

    global_model = torch.load("../projects/pretrained_model/cifar100_predefined_a03_56c_fedavg/last_model.pth.tar")

    print(f"========= Client {client_id} =========")
    global_train_acc = eval(train_loader, global_model, debug=False)
    global_test_acc = eval(test_loader, global_model, debug=False)
# Out:
# ========= Client 0 =========
# Test accuracy: 90.50% (time =     0.00s)
# Test accuracy: 36.54% (time =     0.00s)
# ========= Client 1 =========
# Test accuracy: 94.00% (time =     0.00s)
# Test accuracy: 29.86% (time =     0.00s)
# ========= Client 2 =========
# Test accuracy: 98.15% (time =     0.00s)
# Test accuracy: 38.24% (time =     0.00s)
# ========= Client 3 =========
# Test accuracy: 89.04% (time =     0.00s)
# Test accuracy: 38.98% (time =     0.00s)
# ========= Client 4 =========
# Test accuracy: 96.24% (time =     0.00s)
# Test accuracy: 28.46% (time =     0.00s)
# ========= Client 5 =========
# Test accuracy: 98.53% (time =     0.00s)
# Test accuracy: 36.26% (time =     0.00s)
# ========= Client 6 =========
# Test accuracy: 94.32% (time =     0.00s)
# Test accuracy: 34.81% (time =     0.00s)
# ========= Client 7 =========
# Test accuracy: 88.74% (time =     0.00s)
# Test accuracy: 39.22% (time =     0.00s)
# ========= Client 8 =========
# Test accuracy: 98.28% (time =     0.00s)
# Test accuracy: 43.91% (time =     0.00s)
# ========= Client 9 =========
# Test accuracy: 92.02% (time =     0.00s)
# Test accuracy: 36.52% (time =     0.00s)
# ========= Client 10 =========
# Test accuracy: 98.52% (time =     0.00s)
# Test accuracy: 38.89% (time =     0.00s)
# ========= Client 11 =========
# Test accuracy: 93.12% (time =     0.00s)
# Test accuracy: 31.62% (time =     0.00s)
# ========= Client 12 =========
# Test accuracy: 99.03% (time =     0.00s)
# Test accuracy: 38.32% (time =     0.00s)
# ========= Client 13 =========
# Test accuracy: 91.23% (time =     0.00s)
# Test accuracy: 39.10% (time =     0.00s)
# ========= Client 14 =========
# Test accuracy: 99.39% (time =     0.00s)
# Test accuracy: 40.58% (time =     0.00s)
# ========= Client 15 =========
# Test accuracy: 98.63% (time =     0.00s)
# Test accuracy: 38.29% (time =     0.00s)
# ========= Client 16 =========
# Test accuracy: 89.08% (time =     0.00s)
# Test accuracy: 35.40% (time =     0.00s)
# ========= Client 17 =========
# Test accuracy: 95.02% (time =     0.00s)
# Test accuracy: 41.26% (time =     0.00s)
# ========= Client 18 =========
# Test accuracy: 92.59% (time =     0.00s)
# Test accuracy: 36.26% (time =     0.00s)
# ========= Client 19 =========
# Test accuracy: 86.85% (time =     0.00s)
# Test accuracy: 30.69% (time =     0.00s)
# ========= Client 20 =========
# Test accuracy: 94.57% (time =     0.00s)
# Test accuracy: 39.63% (time =     0.00s)
# ========= Client 21 =========
# Test accuracy: 87.05% (time =     0.00s)
# Test accuracy: 34.98% (time =     0.00s)
# ========= Client 22 =========
# Test accuracy: 93.55% (time =     0.00s)
# Test accuracy: 42.75% (time =     0.00s)
# ========= Client 23 =========
# Test accuracy: 97.06% (time =     0.00s)
# Test accuracy: 41.91% (time =     0.00s)
# ========= Client 24 =========
# Test accuracy: 97.65% (time =     0.00s)
# Test accuracy: 42.96% (time =     0.00s)
# ========= Client 25 =========
# Test accuracy: 86.62% (time =     0.00s)
# Test accuracy: 34.74% (time =     0.00s)
# ========= Client 26 =========
# Test accuracy: 95.31% (time =     0.00s)
# Test accuracy: 36.49% (time =     0.00s)
# ========= Client 27 =========
# Test accuracy: 98.33% (time =     0.00s)
# Test accuracy: 34.29% (time =     0.00s)
# ========= Client 28 =========
# Test accuracy: 93.21% (time =     0.00s)
# Test accuracy: 34.32% (time =     0.00s)
# ========= Client 29 =========
# Test accuracy: 76.16% (time =     0.00s)
# Test accuracy: 22.46% (time =     0.00s)
# ========= Client 30 =========
# Test accuracy: 96.27% (time =     0.00s)
# Test accuracy: 39.55% (time =     0.00s)
# ========= Client 31 =========
# Test accuracy: 94.82% (time =     0.00s)
# Test accuracy: 37.86% (time =     0.00s)
# ========= Client 32 =========
# Test accuracy: 91.82% (time =     0.00s)
# Test accuracy: 33.83% (time =     0.00s)
# ========= Client 33 =========
# Test accuracy: 96.42% (time =     0.00s)
# Test accuracy: 35.71% (time =     0.00s)
# ========= Client 34 =========
# Test accuracy: 97.60% (time =     0.00s)
# Test accuracy: 46.76% (time =     0.00s)
# ========= Client 35 =========
# Test accuracy: 96.41% (time =     0.00s)
# Test accuracy: 40.24% (time =     0.00s)
# ========= Client 36 =========
# Test accuracy: 85.43% (time =     0.00s)
# Test accuracy: 34.31% (time =     0.00s)
# ========= Client 37 =========
# Test accuracy: 92.47% (time =     0.00s)
# Test accuracy: 32.73% (time =     0.00s)
# ========= Client 38 =========
# Test accuracy: 98.73% (time =     0.00s)
# Test accuracy: 35.74% (time =     0.00s)
# ========= Client 39 =========
# Test accuracy: 96.52% (time =     0.00s)
# Test accuracy: 43.87% (time =     0.00s)
# ========= Client 40 =========
# Test accuracy: 95.04% (time =     0.00s)
# Test accuracy: 34.98% (time =     0.00s)
# ========= Client 41 =========
# Test accuracy: 94.78% (time =     0.00s)
# Test accuracy: 37.69% (time =     0.00s)
# ========= Client 42 =========
# Test accuracy: 97.52% (time =     0.00s)
# Test accuracy: 33.92% (time =     0.00s)
# ========= Client 43 =========
# Test accuracy: 96.01% (time =     0.00s)
# Test accuracy: 32.61% (time =     0.00s)
# ========= Client 44 =========
# Test accuracy: 98.45% (time =     0.00s)
# Test accuracy: 42.35% (time =     0.00s)
# ========= Client 45 =========
# Test accuracy: 96.17% (time =     0.00s)
# Test accuracy: 37.63% (time =     0.00s)
# ========= Client 46 =========
# Test accuracy: 96.70% (time =     0.00s)
# Test accuracy: 44.32% (time =     0.00s)
# ========= Client 47 =========
# Test accuracy: 91.29% (time =     0.00s)
# Test accuracy: 26.81% (time =     0.00s)
# ========= Client 48 =========
# Test accuracy: 93.80% (time =     0.00s)
# Test accuracy: 34.67% (time =     0.00s)
# ========= Client 49 =========
# Test accuracy: 97.23% (time =     0.00s)
# Test accuracy: 36.33% (time =     0.00s)
# ========= Client 50 =========
# Test accuracy: 93.62% (time =     0.00s)
# Test accuracy: 30.90% (time =     0.00s)
# ========= Client 51 =========
# Test accuracy: 96.55% (time =     0.00s)
# Test accuracy: 42.70% (time =     0.00s)
# ========= Client 52 =========
# Test accuracy: 87.74% (time =     0.00s)
# Test accuracy: 30.96% (time =     0.00s)
# ========= Client 53 =========
# Test accuracy: 98.84% (time =     0.00s)
# Test accuracy: 38.61% (time =     0.00s)
# ========= Client 54 =========
# Test accuracy: 95.53% (time =     0.00s)
# Test accuracy: 41.70% (time =     0.00s)
# ========= Client 55 =========
# Test accuracy: 97.83% (time =     0.00s)
# Test accuracy: 41.16% (time =     0.00s)

# %%
train_dataset_path = os.path.join("../data/32_Cifar100_NIID_56c_a03", "server", f"train.pkl")
train_data = pickle.load(open(train_dataset_path, "rb"))
train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=128,
    shuffle=True)

test_dataset_path = os.path.join("../data/32_Cifar100_NIID_56c_a03", "server", f"test.pkl")
test_data = pickle.load(open(test_dataset_path, "rb"))
test_loader = torch.utils.data.DataLoader(
    test_data,
    batch_size=128,
    shuffle=True)

global_model = torch.load("../projects/pretrained_model/cifar100_predefined_a03_56c_fedavg/last_model.pth.tar")

print(f"========= Server =========")
global_train_acc = eval(train_loader, global_model, debug=False)
global_test_acc = eval(test_loader, global_model, debug=False)
# Out:
# ========= Server =========
# Test accuracy: 79.73% (time =     0.00s)
# Test accuracy: 80.67% (time =     0.00s)

# %%
test_counts = np.zeros((56,100))

# %%
for client_id in range(56):
    train_dataset_path = os.path.join("../data/32_Cifar100_NIID_56c_a03_fix", "train", f"{client_id}.pkl")
    train_data = pickle.load(open(train_dataset_path, "rb"))

    label_counts = np.unique(train_data.labels, return_counts=True)
    for idx in range(len(label_counts[0])):
        label = label_counts[0][idx]
        count = label_counts[1][idx]
        test_counts[client_id][label] = count

# %%
np.sum(test_counts, axis = 0)
# Out:
# array([536., 587., 500., 480., 511., 609., 619., 565., 682., 769., 603.,
#        539., 666., 589., 531., 552., 493., 568., 564., 545., 468., 520.,
#        732., 606., 712., 491., 704., 610., 658., 549., 544., 656., 475.,
#        552., 618., 781., 659., 628., 480., 661., 490., 480., 795., 665.,
#        633., 621., 541., 556., 481., 683., 516., 563., 598., 597., 511.,
#        611., 535., 597., 590., 646., 730., 484., 541., 727., 513., 547.,
#        544., 667., 623., 487., 534., 576., 479., 703., 607., 481., 579.,
#        474., 535., 743., 665., 764., 568., 611., 750., 521., 768., 786.,
#        682., 786., 662., 593., 852., 834., 669., 788., 754., 755., 593.,
#        884.])
