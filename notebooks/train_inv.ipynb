# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../projects/define_pretrained_fed_sim_NIID_alpha03/federated.txt")
server_data = data[data["ClientNo"] == "server"][["Dataset", "Accuracy"]]

# %%
plt.figure(figsize=(10,5))
train_data = server_data.groupby("Dataset").get_group("train")["Accuracy"].tolist()
test_data = server_data.groupby("Dataset").get_group("test")["Accuracy"].tolist()

# server_data.groupby("Dataset")["Accuracy"].plot(legend=True)
plt.plot(train_data)
plt.plot(train_data)

plt.xticks(np.arange(0,200,10))
plt.show()

# %%
server_data
# Out:
#      Dataset  Accuracy  value
# 19     train    10.004      1
# 20      test    10.000      1
# 34     train    10.108      1
# 35      test    10.040      1
# 53     train    10.000      1
# ...      ...       ...    ...
# 3168    test    42.630      1
# 3183   train    42.204      1
# 3184    test    42.330      1
# 3198   train    42.644      1
# 3199    test    42.760      1
#
# [400 rows x 3 columns]
