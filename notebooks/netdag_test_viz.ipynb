# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/alpha/test_03.csv")

# %%
df[df["alpha"] == 0.7]
# Out:
#      Unnamed: 0  alpha  no_clients  coeff  max_iter  initial_emd       emd  \
# 48           48    0.7          56    0.5         5     0.402768  0.214975
# 49           49    0.7          56    0.5        10     0.369257  0.216029
# 50           50    0.7          56    0.5        20     0.418755  0.186972
# 51           51    0.7          56    0.5        50     0.364689  0.195220
# 52           52    0.7          56    0.7         5     0.390089  0.203960
# 53           53    0.7          56    0.7        10     0.405894  0.204033
# 54           54    0.7          56    0.7        20     0.403012  0.213186
# 55           55    0.7          56    0.7        50     0.349803  0.216232
# 56           56    0.7          56    0.9         5     0.447306  0.149476
# 57           57    0.7          56    0.9        10     0.383637  0.164114
# 58           58    0.7          56    0.9        20     0.375211  0.147296
# ...

# %%
dfviz = df[df["no_clients"] == 56]

fig = px.scatter_3d(dfviz, x='alpha', y='coeff', z='emd',
              color='emd')
            
fig.update_layout(
    height=500
)
fig.show()

# %%
dfviz
# Out:
#      Unnamed: 0  alpha  no_clients  coeff  max_iter  initial_emd       emd  \
# 16           16    0.3          56    0.5         5     0.615875  0.299564
# 17           17    0.3          56    0.5        10     0.558290  0.275294
# 18           18    0.3          56    0.5        20     0.555644  0.309373
# 19           19    0.3          56    0.5        50     0.587775  0.375280
# 20           20    0.3          56    0.7         5     0.556951  0.275366
# 21           21    0.3          56    0.7        10     0.498012  0.289327
# 22           22    0.3          56    0.7        20     0.526520  0.254293
# 23           23    0.3          56    0.7        50     0.485939  0.311428
# 24           24    0.3          56    0.9         5     0.569757  0.282644
# 25           25    0.3          56    0.9        10     0.488751  0.288280
# 26           26    0.3          56    0.9        20     0.514859  0.196744
# ...

# %%
dfviz = df[df["alpha"] == 0.3]

fig = px.scatter_3d(dfviz, x='no_clients', y='coeff', z='download_duration',
              color='emd')
            
fig.update_layout(
    height=500
)
fig.show()

# %%
# alpha vs emd (initial condition) vs final cond.
# total duration vs netdag duration
# group bw bottleneck parameter
# Coeff daha küçük değerler
